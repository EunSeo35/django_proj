# %%
import re

# %%
string = 'hello y1k1234@gmail.com 010-222-3333 world 02-1345-2345$'
print('1')
# Out:
# 1

# %%
pattern = re.compile(r'\d{2,3}-\d{3,4}-\d{4}')
pattern.findall(string)
# Out:
# ['010-222-3333', '02-1345-2345']
